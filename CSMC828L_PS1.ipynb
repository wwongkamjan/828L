# %%
# !git clone -b master https://github.com/wwongkamjan/828L.git
# Out:
# Cloning into '828L'...
# remote: Enumerating objects: 1532, done.
# remote: Counting objects: 100% (311/311), done.
# remote: Compressing objects: 100% (205/205), done.
# remote: Total 1532 (delta 206), reused 210 (delta 106), pack-reused 1221
# Receiving objects: 100% (1532/1532), 288.94 KiB | 3.85 MiB/s, done.
# Resolving deltas: 100% (1014/1014), done.

# %%
cd solution
# Out:
# /content/solution

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/wwongkamjan/828L
#    3f90869..3a551cb  master     -> origin/master
# Updating 3f90869..3a551cb
# Fast-forward
#  sol_2b.py | 4 ++--
#  1 file changed, 2 insertions(+), 2 deletions(-)

# %%
# !git stash
# Out:
# No local changes to save

# %%
# !python sol_1a.py
# Out:
# 0.008974432045539204
# w [[7.00940886]]
# b [[2.90861135]]
# predict:  [-10.63499221]  label:  [-10.42830273]
# predict:  [-9.68456389]  label:  [-9.56384265]
# predict:  [-8.73413557]  label:  [-8.60321257]
# predict:  [-7.78370725]  label:  [-7.7617405]
# predict:  [-6.83327893]  label:  [-6.62363711]
# predict:  [-5.88285061]  label:  [-5.73659352]
# predict:  [-4.93242229]  label:  [-4.91460542]
# predict:  [-3.98199397]  label:  [-3.95011798]
# predict:  [-3.03156565]  label:  [-2.90695719]
# predict:  [-2.08113733]  label:  [-1.96838915]
# predict:  [-1.13070901]  label:  [-0.96083178]
# predict:  [-0.18028069]  label:  [-0.09949559]
# predict:  [0.77014763]  label:  [0.97080216]
# predict:  [1.72057595]  label:  [1.9407846]
# predict:  [2.67100427]  label:  [2.81941469]
# predict:  [3.62143259]  label:  [3.6356579]
# predict:  [4.57186091]  label:  [4.73780589]
# predict:  [5.52228922]  label:  [5.64331859]
# predict:  [6.47271754]  label:  [6.34621873]
# ...

# %%
# !python sol_1b.py
# Out:
# 0.019849507323924192
# predict:  [2.01541307]  label:  [1.90153745]
# predict:  [1.61753921]  label:  [1.45818308]
# predict:  [1.21966534]  label:  [1.3498659]
# predict:  [0.82179148]  label:  [0.68311672]
# predict:  [0.42391761]  label:  [0.48549932]
# predict:  [0.02604375]  label:  [-0.01461951]
# predict:  [-0.37183012]  label:  [-0.43608671]
# predict:  [-0.76970398]  label:  [-0.98080609]
# predict:  [-1.16757785]  label:  [-1.3723957]
# predict:  [-1.56545171]  label:  [-1.56788]
# predict:  [-1.96332558]  label:  [-1.96376191]
# predict:  [-2.36119944]  label:  [-2.59420049]
# predict:  [-2.75907331]  label:  [-3.12158556]
# predict:  [-3.15694717]  label:  [-3.31119799]
# predict:  [-3.55482104]  label:  [-3.65361135]
# predict:  [-3.9526949]  label:  [-4.28795918]
# predict:  [-4.35056877]  label:  [-4.64771972]
# predict:  [-4.74844263]  label:  [-4.9435815]
# predict:  [-5.1463165]  label:  [-5.43672467]
# predict:  [-5.54419036]  label:  [-5.65084696]
# ...

# %%
# !python sol_2a.py
# Out:
# 0.0009999151933212838
# w1 [[-0.10268372]
#  [-0.26083729]
#  [-0.41937952]
#  [-0.31579599]
#  [-0.1207955 ]
#  [ 0.70278652]
#  [ 0.23395891]
#  [-0.20965382]
#  [ 0.35693086]
#  [-0.44119767]]
# b1 [[ 0.1044333  -0.16190712 -0.05798661  0.01984719  0.12837547  0.01983944
#    0.29175646  0.20857329 -0.12012928 -0.00638137]]
# w2 [[-0.91328616  1.12122926  0.54879942 -0.15922915 -1.17680365  0.04212211
#    1.97852124 -1.82903313 -0.96344143  0.126527  ]]
# b2 [[0.02133505]]
# [[-1.00641403]
#  [-0.98124359]
#  [-0.95607314]
#  [-0.8963581 ]
#  [-0.74349312]
#  [-0.59061905]
#  [-0.35707589]
#  [-0.10758249]
#  [ 0.20152594]
#  [ 0.45798017]
#  [ 0.66984487]
#  [ 0.86487444]
#  [ 0.9098896 ]
#  [ 0.95088644]
#  [ 0.99188328]]

# %%
# !git pull
# !python sol_2b.py
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/wwongkamjan/828L
#    6a584e4..55e5a34  master     -> origin/master
# Updating 6a584e4..55e5a34
# Fast-forward
#  sol_2b.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# 0.08321836253758443
# predict:  [6.57597576]  label:  [7.22296964]
# predict:  [6.75219741]  label:  [7.29452688]
# predict:  [6.89933984]  label:  [7.3971704]
# predict:  [6.97607541]  label:  [7.43452564]
# predict:  [7.05281099]  label:  [7.53655978]
# predict:  [7.12954656]  label:  [7.61166914]
# predict:  [7.20628214]  label:  [7.68751298]
# predict:  [7.28301771]  label:  [7.85349959]
# predict:  [7.35975328]  label:  [7.97811253]
# predict:  [7.43648886]  label:  [7.77434083]
# predict:  [7.51322443]  label:  [7.87090283]
# ...

# %%
# !git pull
# !python sol_3a.py
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/wwongkamjan/828L
#    0e06606..552dc9f  master     -> origin/master
# Updating 0e06606..552dc9f
# Fast-forward
#  sol_3a.py | 3 +--
#  1 file changed, 1 insertion(+), 2 deletions(-)
# 1.2035976652408544e-05
# predict:  [-0.93122316]  label:  [-0.94085667]
# predict:  [-0.97782813]  label:  [-0.98254829]
# predict:  [-0.97064242]  label:  [-0.93262368]
# predict:  [-0.85714289]  label:  [-0.8453402]
# predict:  [-0.69282743]  label:  [-0.67942888]
# predict:  [-0.48349669]  label:  [-0.50033131]
# predict:  [-0.2723544]  label:  [-0.20100266]
# predict:  [-0.01817998]  label:  [0.08830751]
# predict:  [0.34124118]  label:  [0.34268464]
# predict:  [0.59682813]  label:  [0.56116766]
# predict:  [0.78721653]  label:  [0.80687903]
# ...

# %%
# !git pull

# !python sol_3b.py
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/wwongkamjan/828L
#    aa49db2..bcc824d  master     -> origin/master
# Updating aa49db2..bcc824d
# Fast-forward
#  sol_3b.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# 0.4142423824344005
# <Figure size 640x480 with 1 Axes>

# %%
# !git pull

# !python sol_4b.py
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/wwongkamjan/828L
#    0cbf9db..8d8d775  master     -> origin/master
# Updating 0cbf9db..8d8d775
# Fast-forward
#  sol_4b.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# <Figure size 640x480 with 1 Axes>

# %%
# !git pull

# !python sol_mnist.py
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/wwongkamjan/828L
#    90759be..3e2618e  master     -> origin/master
# Updating 90759be..3e2618e
# Fast-forward
#  sol_mnist.py | 4 ++--
#  1 file changed, 2 insertions(+), 2 deletions(-)
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py:719: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   val = np.asanyarray(val)
# predict:  3  label:  7
# predict:  4  label:  2
# predict:  5  label:  1
# predict:  6  label:  0
# predict:  7  label:  4
# predict:  8  label:  1
# predict:  9  label:  4
# ...

# %%
# !python public_tests.py
# Out:
# testing sol_1a.py
# 0.004739273654985288
# mse 0.005930116084620288
# Number of tests correct: 3 / 3
# Tests run: ['test_network_arch', 'test_final_mse', 'test_gradients']
# testing sol_1b.py
# 0.0232259797692684
# mse 0.016713486726599388
# Number of tests correct: 3 / 3
# Tests run: ['test_network_arch', 'test_final_mse', 'test_gradients']
# testing sol_2a.py
# 0.0017944540431706476
# mse 0.0022939479827200327
# test_gradients failed
# Number of tests correct: 2 / 3
# Tests run: ['test_network_arch', 'test_final_mse', 'test_gradients']
# testing sol_2b.py
# 0.08309345888586955
# mse 0.08319096327638034
# test_gradients failed
# Number of tests correct: 2 / 3
# Tests run: ['test_network_arch', 'test_final_mse', 'test_gradients']
# testing sol_3a.py
# 1.3089744226874691e-05
# mse 0.0008069814243205871
# test_gradients failed
# Number of tests correct: 2 / 3
# Tests run: ['test_network_arch', 'test_final_mse', 'test_gradients']
# testing sol_3b.py
# Traceback (most recent call last):
# ...

# %%
# 1a
import matplotlib.pyplot as plt
import numpy as np

def func_1(x):
  noise = np.random.normal(0,1)
  # print(noise)
  return 7*x + 3 + noise
w = 6.98777337
b = 2.98399838

train_input_1a = np.random.normal(0,1,100)
train_label_1a = [func_1(x) for x in train_input_1a]
predict_label = train_input_1a*w + b
plt.scatter(train_input_1a, train_label_1a)
plt.plot(train_input_1a, predict_label, color='r')
plt.xlabel('train_input')
plt.ylabel('train_label')
# print(train_input)
# print(train_label)
# Out:
# Text(0, 0.5, 'train_label')

# %%
# 2a
import matplotlib.pyplot as plt
import numpy as np

def func_1(w1,b1,w2,b2,input):
  # noise = np.random.normal(0,1)
  # print(noise)
  return np.dot(np.maximum(np.dot(input, w1.T) + b1, 0), w2.T) + b2
w1 = [[ 1.98627731e-01], [ 5.75530293e-06], [-4.75238000e-01], [-2.00994683e-01],
 [-1.58762354e-01],
 [ 1.50366269e-01],
 [ 1.93986868e-01],
 [ 1.13156615e-01],
 [ 1.31018657e-01], [-3.18327328e-01]]
w1 = np.array(w1)
b1 = [[ 0.05021042, -0.00035845,  0.18817566, -0.02926845,  0.11893162, -0.16330271,
  -0.07403069,  0.07205085,  0.11525127, -0.06536544]]
b1 = np.array(b1)
w2 = [[ 1.32722252,  0.53105207 ,-0.81366669,  0.18335666 ,-0.49637429, -1.72998029,
  -0.94827555 , 1.52656175 , 1.98819867 , 0.39379959]]
w2 = np.array(w2)
b2 =[[-0.19894879]]
b2 = np.array(b2)

train_input_2a= np.linspace(-2, 2, 30)[:, np.newaxis]
train_label_2a= np.sin(train_input_2a) + np.random.randn(30, 1)*0.02
predict_label = func_1(w1,b1,w2,b2,train_input_2a)
print(predict_label)
plt.scatter(train_input_2a, train_label_2a)
plt.plot(train_input_2a, predict_label, color='r')
plt.xlabel('train_input')
plt.ylabel('train_label')
# print(train_input)
# print(train_label)
# Out:
# [[-1.0487631 ]
#  [-1.00693137]
#  [-0.96509965]
#  [-0.92326793]
#  [-0.8814362 ]
#  [-0.83960448]
#  [-0.79777275]
#  [-0.75594103]
#  [-0.71410931]
#  [-0.64074911]
#  [-0.56021579]
#  [-0.45862797]
#  [-0.35704015]
#  [-0.24335467]
#  [-0.08548454]
#  [ 0.07483902]
#  [ 0.23516257]
#  [ 0.39548612]
#  [ 0.50364286]
#  [ 0.58525768]
#  [ 0.66612357]
#  [ 0.73686866]
#  [ 0.80761374]
#  [ 0.8558885 ]
#  [ 0.89075349]
#  [ 0.92561848]
#  [ 0.96048347]
#  [ 0.99534847]
#  [ 1.03021346]
#  [ 1.06507845]]
# Text(0, 0.5, 'train_label')

# %%
import matplotlib.pyplot as plt
import numpy as np
    #generating data
x = np.linspace(-2, 2, 30)[:, np.newaxis]
y = np.where(x > 0, 1, 0)
y[25:,:] = 0

x_train = x[::2]
y_train = y[::2]
x_test = x[1::2]
y_test = y[1::2]

plt.scatter(x, y)
plt.xlabel('train_input')
plt.ylabel('train_label')
# Out:
# Text(0, 0.5, 'train_label')
